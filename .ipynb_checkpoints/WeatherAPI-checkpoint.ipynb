# %% [markdown]
# # WeatherAPI
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 613

# %%
cities[0:5]
# Out:
# ['ushuaia', 'vilyuchinsk', 'grytviken', 'howrah', 'port elizabeth']

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).
#
# > **HINT:** The OpenWeatherMap API only allows 60 calls per minute under their free plan. Try using `time.sleep(60)` after each set of 50 cities to avoid API errors due to large calls.

# %%
url = "https://api.openweathermap.org/data/2.5/weather?"
total_cities = len(cities)
count = 0
time_count = 0
valid_cities = []
lat = []
lng = []
max_temp = []
humidity = []
cloudiness = []
wind_speed = []
country = []
date = []

for city in cities:
    count += 1
    if time_count < 50:
        try:
            query_url = f"{url}appid={weather_api_key}&q={city}"
            weather_response = requests.get(query_url)
            weather_json = weather_response.json()
            valid_cities.append(city)
            lat.append(weather_json['coord']['lat'])
            lng.append(weather_json['coord']['lon'])
            max_temp.append(weather_json['main']['temp_max'])
            humidity.append(weather_json['main']['humidity'])
            cloudiness.append(weather_json['clouds']['all'])
            wind_speed.append(weather_json['wind']['speed'])
            country.append(weather_json['sys']['country'])
            date.append(weather_json['dt'])
            print(f'city #{count} of {total_cities}: {city} data processed')
        except:
            print(f'city #{count} of {total_cities}: {city} data unavailable')
        time_count += 1
    else:
        time.sleep(60)
        time_count = 0
        
city_data = pd.DataFrame({'City': valid_cities,
                          'Lat': lat,
                          'Long': lng,
                          'Max Temp': max_temp,
                          'Humidity': humidity,
                          'Cloudiness': cloudiness,
                          'Wind Speed': wind_speed,
                          'Country': country,
                          'Date': date})
# Out:
# city #1 of 613: ushuaia data processed
# city #2 of 613: vilyuchinsk data processed
# city #3 of 613: grytviken data processed
# city #4 of 613: howrah data processed
# city #5 of 613: port elizabeth data processed
# city #6 of 613: port mathurin data processed
# city #7 of 613: venustiano carranza data processed
# city #8 of 613: stjordalshalsen data processed
# city #9 of 613: yaren data processed
# city #10 of 613: nova vicosa data processed
# city #11 of 613: college data processed
# city #12 of 613: thompson data processed
# city #13 of 613: iqaluit data processed
# city #14 of 613: ouellah data unavailable
# city #15 of 613: albany data processed
# city #16 of 613: jamestown data processed
# city #17 of 613: praia da vitoria data processed
# city #18 of 613: adamstown data processed
# city #19 of 613: harper data processed
# city #20 of 613: midvagur data processed
# city #21 of 613: tolanaro data processed
# city #22 of 613: invercargill data processed
# city #23 of 613: touros data processed
# city #24 of 613: choele choel data processed
# city #25 of 613: puerto san carlos data unavailable
# city #26 of 613: sitka data processed
# city #27 of 613: taiohae data unavailable
# city #28 of 613: edinburgh of the seven seas data processed
# city #29 of 613: arraial do cabo data processed
# city #30 of 613: tiksi data processed
# city #31 of 613: mount pearl data processed
# city #32 of 613: vorgashor data processed
# city #33 of 613: tabou data processed
# city #34 of 613: carnarvon data processed
# city #35 of 613: klyuchi data processed
# city #36 of 613: dudinka data processed
# city #37 of 613: afaahiti data processed
# city #38 of 613: tralee data processed
# city #39 of 613: blackmans bay data processed
# city #40 of 613: manismata data processed
# city #41 of 613: bethel data processed
# city #42 of 613: kailua-kona data processed
# city #43 of 613: anadyr data processed
# city #44 of 613: longyearbyen data processed
# city #45 of 613: gadzhiyevo data processed
# city #46 of 613: yellowknife data processed
# city #47 of 613: ha tinh data processed
# city #48 of 613: bilibino data processed
# city #49 of 613: salalah data processed
# city #50 of 613: broome data processed
# city #52 of 613: waitangi data processed
# city #53 of 613: port-aux-francais data processed
# city #54 of 613: margaret river data processed
# city #55 of 613: aasiaat data processed
# city #56 of 613: dem'yanovo data processed
# city #57 of 613: tuy hoa data processed
# city #58 of 613: belmonte data processed
# city #59 of 613: badger data processed
# city #60 of 613: bethanie data processed
# city #61 of 613: stanley data processed
# city #62 of 613: kodiak data processed
# city #63 of 613: governor's harbour data unavailable
# city #64 of 613: tibro data processed
# city #65 of 613: happy valley-goose bay data processed
# city #66 of 613: puerto ayora data processed
# city #67 of 613: carutapera data processed
# city #68 of 613: leava data processed
# city #69 of 613: cikarang data processed
# city #70 of 613: hamilton data processed
# city #71 of 613: hotan data processed
# city #72 of 613: port saint john's data processed
# city #73 of 613: mili data processed
# city #74 of 613: uva data processed
# city #75 of 613: lata data processed
# city #76 of 613: wa data unavailable
# city #77 of 613: constantia data processed
# city #78 of 613: aykhal data processed
# city #79 of 613: east london data processed
# city #80 of 613: bien unido data processed
# city #81 of 613: salavan data processed
# city #82 of 613: san jose village data unavailable
# city #83 of 613: tanout data processed
# city #84 of 613: uturoa data processed
# city #85 of 613: jinchang data processed
# city #86 of 613: bardai data processed
# city #87 of 613: swakopmund data processed
# city #88 of 613: isafjordur data processed
# city #89 of 613: ternate data processed
# city #90 of 613: mossel bay data processed
# city #91 of 613: tura data processed
# city #92 of 613: kapuskasing data processed
# city #93 of 613: berdigestyakh data processed
# city #94 of 613: wailua homesteads data processed
# city #95 of 613: noosa heads data processed
# city #96 of 613: punta arenas data processed
# city #97 of 613: meadow lakes data processed
# city #98 of 613: west island data processed
# city #99 of 613: puerto natales data processed
# city #100 of 613: laguna data processed
# city #101 of 613: makokou data processed
# city #103 of 613: port douglas data processed
# city #104 of 613: san patricio data processed
# city #105 of 613: san antonio de pale data processed
# city #106 of 613: papatowai data processed
# city #107 of 613: kenai data processed
# city #108 of 613: talnakh data processed
# city #109 of 613: savonlinna data processed
# city #110 of 613: kaa-khem data processed
# city #111 of 613: kapa'a data processed
# city #112 of 613: najran data processed
# city #113 of 613: kovdor data processed
# city #114 of 613: port lincoln data processed
# city #115 of 613: fort mcmurray data processed
# city #116 of 613: shache data processed
# city #117 of 613: sorong data processed
# city #118 of 613: kasane data processed
# city #119 of 613: new norfolk data processed
# city #120 of 613: saint peter data processed
# city #121 of 613: port alfred data processed
# city #122 of 613: dunedin data processed
# city #123 of 613: rongelap data processed
# city #124 of 613: ribeira grande data processed
# city #125 of 613: quartu sant'elena data processed
# city #126 of 613: condoto data processed
# city #127 of 613: tamandare data processed
# city #128 of 613: ola data processed
# city #129 of 613: sault ste. marie data processed
# city #130 of 613: hami data processed
# city #131 of 613: aldinga beach data processed
# city #132 of 613: cidade velha data processed
# city #133 of 613: hawaiian paradise park data processed
# city #134 of 613: hithadhoo data processed
# city #135 of 613: remire-montjoly data processed
# city #136 of 613: pacific grove data processed
# city #137 of 613: christchurch data processed
# city #138 of 613: hadibu data processed
# city #139 of 613: nova sintra data processed
# city #140 of 613: geraldton data processed
# city #141 of 613: nelson bay data processed
# city #142 of 613: vradiyivka data processed
# city #143 of 613: la passe data processed
# city #144 of 613: lebu data processed
# city #145 of 613: yeniseysk data processed
# city #146 of 613: abadeh data processed
# city #147 of 613: mahina data processed
# city #148 of 613: whitehorse data processed
# city #149 of 613: twon-brass data processed
# city #150 of 613: mejit data processed
# city #151 of 613: avarua data processed
# city #152 of 613: taoudenni data processed
# city #154 of 613: banda aceh data processed
# city #155 of 613: dondo data processed
# city #156 of 613: turpan data processed
# city #157 of 613: chivhu data processed
# city #158 of 613: moree data processed
# city #159 of 613: beawar data processed
# city #160 of 613: tazovsky data processed
# city #161 of 613: prince rupert data processed
# city #162 of 613: salahonda data processed
# city #163 of 613: jutai data processed
# city #164 of 613: petropavlovsk-kamchatsky data processed
# city #165 of 613: hammerfest data processed
# city #166 of 613: fuvahmulah data unavailable
# city #167 of 613: thames data processed
# city #168 of 613: mareeba data processed
# city #169 of 613: kristiansund data processed
# city #170 of 613: inari data processed
# city #171 of 613: chulym data processed
# city #172 of 613: concepcion del oro data processed
# city #173 of 613: sao joao da barra data processed
# city #174 of 613: abraham's bay data unavailable
# city #175 of 613: ancud data processed
# city #176 of 613: kingston data processed
# city #177 of 613: ko pha ngan data processed
# city #178 of 613: shimoda data processed
# city #179 of 613: urangan data processed
# city #180 of 613: tonghae data processed
# city #181 of 613: enewetak data processed
# city #182 of 613: pangkalpinang data processed
# city #183 of 613: antofagasta data processed
# city #184 of 613: qaqortoq data processed
# city #185 of 613: carthage data processed
# city #186 of 613: utrik data processed
# city #187 of 613: yangor data unavailable
# city #188 of 613: kingscliff data processed
# city #189 of 613: sumbawanga data processed
# city #190 of 613: filadelfia data processed
# city #191 of 613: bubaque data processed
# city #192 of 613: chonchi data processed
# city #193 of 613: amuntai data processed
# city #194 of 613: layyah data processed
# city #195 of 613: krasnozerskoye data processed
# city #196 of 613: newnham data processed
# city #197 of 613: nuku'alofa data processed
# city #198 of 613: barreiras data processed
# city #199 of 613: newman data processed
# city #200 of 613: suva data processed
# city #201 of 613: shiprock data processed
# city #202 of 613: mariental data processed
# city #203 of 613: igarka data processed
# city #205 of 613: ramhormoz data processed
# city #206 of 613: lwowek slaski data processed
# city #207 of 613: olonkinbyen data processed
# city #208 of 613: kalabo data processed
# city #209 of 613: colonia data processed
# city #210 of 613: yelizovo data processed
# city #211 of 613: copala data processed
# city #212 of 613: kegen data processed
# city #213 of 613: kone data processed
# city #214 of 613: gunjur data processed
# city #215 of 613: almeirim data processed
# city #216 of 613: poco branco data processed
# city #217 of 613: lihue data processed
# city #218 of 613: kirakira data processed
# city #219 of 613: sofifi data unavailable
# city #220 of 613: markaz-e woluswali-ye achin data processed
# city #221 of 613: petawawa data processed
# city #222 of 613: guiping data processed
# city #223 of 613: prince george data processed
# city #224 of 613: sabancuy data processed
# city #225 of 613: palikir - national government center data processed
# city #226 of 613: aydarken data processed
# city #227 of 613: tutoia data processed
# city #228 of 613: sur data processed
# city #229 of 613: greymouth data processed
# city #230 of 613: safford data processed
# city #231 of 613: camapua data processed
# city #232 of 613: weno data processed
# city #233 of 613: hun data processed
# city #234 of 613: muisne data processed
# city #235 of 613: vila velha data processed
# city #236 of 613: rexburg data processed
# city #237 of 613: mokhsogollokh data processed
# city #238 of 613: hacienda huancane data processed
# city #239 of 613: naze data processed
# city #240 of 613: hermanus data processed
# city #241 of 613: progreso data processed
# city #242 of 613: cadale data processed
# city #243 of 613: sopela data processed
# city #244 of 613: la ronge data processed
# city #245 of 613: valognes data processed
# city #246 of 613: myeik data processed
# city #247 of 613: susuman data processed
# city #248 of 613: buka data processed
# city #249 of 613: lugulu data processed
# city #250 of 613: bambari data processed
# city #251 of 613: parabel' data processed
# city #252 of 613: weleri data processed
# city #253 of 613: labrador city data processed
# city #254 of 613: nkowakowa data processed
# city #256 of 613: kuraymah data processed
# city #257 of 613: binbrook data processed
# city #258 of 613: wynyard data processed
# city #259 of 613: belyy yar data processed
# city #260 of 613: timimoun data processed
# city #261 of 613: malango data processed
# city #262 of 613: tucuma data processed
# city #263 of 613: bredasdorp data processed
# city #264 of 613: tashtyp data processed
# city #265 of 613: vernon data processed
# city #266 of 613: karratha data processed
# city #267 of 613: rio preto da eva data processed
# city #268 of 613: dahab data processed
# city #269 of 613: glace bay data processed
# city #270 of 613: illizi data processed
# city #271 of 613: polyarnyy data processed
# city #272 of 613: kuruman data processed
# city #273 of 613: grand haven data processed
# city #274 of 613: guerrero negro data processed
# city #275 of 613: aras-asan data processed
# city #276 of 613: ilulissat data processed
# city #277 of 613: morant bay data processed
# city #278 of 613: xinyu data processed
# city #279 of 613: bokovskaya data processed
# city #280 of 613: nouadhibou data processed
# city #281 of 613: morehead city data processed
# city #282 of 613: atafu village data processed
# city #283 of 613: deder data processed
# city #284 of 613: cooper's town data processed
# city #285 of 613: oleszyce data processed
# city #286 of 613: ascension data processed
# city #287 of 613: portland data processed
# city #288 of 613: desarmes data processed
# city #289 of 613: markovo data processed
# city #290 of 613: holualoa data processed
# city #291 of 613: piacabucu data processed
# city #292 of 613: vadso data processed
# city #293 of 613: flintbek data processed
# city #294 of 613: saksaul'skiy data unavailable
# city #295 of 613: pangody data processed
# city #296 of 613: flying fish cove data processed
# city #297 of 613: katsuura data processed
# city #298 of 613: georgetown data processed
# city #299 of 613: george town data processed
# city #300 of 613: namibe data processed
# city #301 of 613: arenapolis data processed
# city #302 of 613: sechura data processed
# city #303 of 613: gornopravdinsk data processed
# city #304 of 613: brasileia data processed
# city #305 of 613: le port data processed
# city #307 of 613: prado data processed
# city #308 of 613: sedro-woolley data processed
# city #309 of 613: makushino data processed
# city #310 of 613: st. john's data processed
# city #311 of 613: port-gentil data processed
# city #312 of 613: ciudad gustavo diaz ordaz data processed
# city #313 of 613: cockburn town data processed
# city #314 of 613: argo data processed
# city #315 of 613: tehran data processed
# city #316 of 613: linhares data processed
# city #317 of 613: bima data processed
# city #318 of 613: iwon-up data processed
# city #319 of 613: kushiro data processed
# city #320 of 613: tchintabaraden data processed
# city #321 of 613: akureyri data processed
# city #322 of 613: port pirie data processed
# city #323 of 613: kasongo data processed
# city #324 of 613: bejubang dua data unavailable
# city #325 of 613: rawdon data processed
# city #326 of 613: mana data processed
# city #327 of 613: crane data processed
# city #328 of 613: severo-yeniseyskiy data processed
# city #329 of 613: yuzhno-kurilsk data processed
# city #330 of 613: iskateley data processed
# city #331 of 613: tofol data processed
# city #332 of 613: fale old settlement data processed
# city #333 of 613: fort wellington data processed
# city #334 of 613: altagracia de orituco data processed
# city #335 of 613: castel data processed
# city #336 of 613: 'ohonua data unavailable
# city #337 of 613: omalur data processed
# city #338 of 613: warwick data processed
# city #339 of 613: zyrya data processed
# city #340 of 613: gargalianoi data processed
# city #341 of 613: bulawayo data processed
# city #342 of 613: keflavik data processed
# city #343 of 613: divino das laranjeiras data processed
# city #344 of 613: norrtalje data processed
# city #345 of 613: grand falls-windsor data processed
# city #346 of 613: ketchikan data processed
# city #347 of 613: galappo data processed
# city #348 of 613: airdrie data processed
# city #349 of 613: lethem data processed
# city #350 of 613: sinabang data processed
# city #351 of 613: roscommon data processed
# city #352 of 613: jose mariano jimenez data unavailable
# city #353 of 613: rosenfeld data processed
# city #354 of 613: jackson data processed
# city #355 of 613: tranovaho data unavailable
# city #356 of 613: ardabil data processed
# city #358 of 613: trairi data processed
# city #359 of 613: sonsorol village data unavailable
# city #360 of 613: qui nhon data processed
# city #361 of 613: lompoc data processed
# city #362 of 613: udachny data processed
# city #363 of 613: kidal data processed
# city #364 of 613: male data processed
# city #365 of 613: makhjan data processed
# city #366 of 613: mar del plata data processed
# city #367 of 613: farafangana data processed
# city #368 of 613: guiren data processed
# city #369 of 613: tay ninh data processed
# city #370 of 613: conde data processed
# city #371 of 613: liupanshui data unavailable
# city #372 of 613: brookings data processed
# city #373 of 613: selfoss data processed
# city #374 of 613: la'ie data processed
# city #375 of 613: priyutnoye data processed
# city #376 of 613: caconda data processed
# city #377 of 613: nagqu data processed
# city #378 of 613: kericho data processed
# city #379 of 613: richards bay data processed
# city #380 of 613: dolisie data processed
# city #381 of 613: akniste data processed
# city #382 of 613: macau data processed
# city #383 of 613: san clemente del tuyu data processed
# city #384 of 613: shush data processed
# city #385 of 613: queenstown data processed
# city #386 of 613: pachino data processed
# city #387 of 613: bir hadaj data unavailable
# city #388 of 613: atar data processed
# city #389 of 613: laojunmiao data processed
# city #390 of 613: vizinga data processed
# city #391 of 613: fort-shevchenko data processed
# city #392 of 613: america dourada data processed
# city #393 of 613: curvelo data processed
# city #394 of 613: kalmunai data processed
# city #395 of 613: baiti data processed
# city #396 of 613: ha giang data processed
# city #397 of 613: monte alegre data processed
# city #398 of 613: wotho data processed
# city #399 of 613: al bawiti data processed
# city #400 of 613: strezhevoy data processed
# city #401 of 613: egilsstadir data processed
# city #402 of 613: san clemente data processed
# city #403 of 613: fuling data processed
# city #404 of 613: adh dhayd data processed
# city #405 of 613: tselinnoye data processed
# city #406 of 613: hasaki data processed
# city #407 of 613: anchau data processed
# city #409 of 613: cabedelo data processed
# city #410 of 613: broken hill data processed
# city #411 of 613: nantucket data processed
# city #412 of 613: maputo data processed
# city #413 of 613: amahai data processed
# city #414 of 613: nar'yan-mar data processed
# city #415 of 613: alotau data unavailable
# city #416 of 613: kagoshima data processed
# city #417 of 613: havre data processed
# city #418 of 613: binghamton data processed
# city #419 of 613: saint-pierre data processed
# city #420 of 613: fisterra data processed
# city #421 of 613: coquimbo data processed
# city #422 of 613: balangir data processed
# city #423 of 613: taitung city data processed
# city #424 of 613: madaba data processed
# city #425 of 613: ar ruways data processed
# city #426 of 613: naryn data processed
# city #427 of 613: deoli data processed
# city #428 of 613: manggar data processed
# city #429 of 613: porto cristo data processed
# city #430 of 613: san miguel de cauri data processed
# city #431 of 613: luderitz data processed
# city #432 of 613: yenisarbademli data processed
# city #433 of 613: saipan data processed
# city #434 of 613: gurlan data processed
# city #435 of 613: rabigh data processed
# city #436 of 613: hsinchu data processed
# city #437 of 613: mogadishu data processed
# city #438 of 613: santa maria data processed
# city #439 of 613: murghob data processed
# city #440 of 613: livingstone data processed
# city #441 of 613: sosnogorsk data processed
# city #442 of 613: iyidere data processed
# city #443 of 613: phan thiet data processed
# city #444 of 613: lekki data unavailable
# city #445 of 613: east honolulu data unavailable
# city #446 of 613: brezina data processed
# city #447 of 613: alice springs data processed
# city #448 of 613: kendari data processed
# city #449 of 613: mandera data processed
# city #450 of 613: bamboo flat data processed
# city #451 of 613: amungan data processed
# city #452 of 613: alaghsas data processed
# city #453 of 613: phalaborwa data processed
# city #454 of 613: sarykemer data processed
# city #455 of 613: gaspe data processed
# city #456 of 613: akot data processed
# city #457 of 613: mathba data processed
# city #458 of 613: mount isa data processed
# city #460 of 613: ghat data processed
# city #461 of 613: kruisfontein data processed
# city #462 of 613: joshimath data processed
# city #463 of 613: tsiombe data processed
# city #464 of 613: promyshlennaya data processed
# city #465 of 613: smithville data processed
# city #466 of 613: carmo do paranaiba data processed
# city #467 of 613: chibougamau data processed
# city #468 of 613: el nido data processed
# city #469 of 613: rawai data processed
# city #470 of 613: charters towers data processed
# city #471 of 613: xixiang data processed
# city #472 of 613: lorengau data processed
# city #473 of 613: lhuentse data processed
# city #474 of 613: toga village data unavailable
# city #475 of 613: nikolayevsk-on-amure data processed
# city #476 of 613: mount gambier data processed
# city #477 of 613: cargados carajos data unavailable
# city #478 of 613: el calafate data processed
# city #479 of 613: flin flon data processed
# city #480 of 613: new plymouth data processed
# city #481 of 613: houghton data processed
# city #482 of 613: umiray data processed
# city #483 of 613: margate data processed
# city #484 of 613: bantogon data processed
# city #485 of 613: valabhipur data processed
# city #486 of 613: nobres data processed
# city #487 of 613: as sulayyil data processed
# city #488 of 613: hinis data processed
# city #489 of 613: ryotsu-minato data processed
# city #490 of 613: okha data processed
# city #491 of 613: irymple data processed
# city #492 of 613: tahara data processed
# city #493 of 613: yigou data processed
# city #494 of 613: tamanrasset data processed
# city #495 of 613: buala data processed
# city #496 of 613: takoradi data processed
# city #497 of 613: acarau data processed
# city #498 of 613: chyorny yar data processed
# city #499 of 613: singkil data processed
# city #500 of 613: forster data processed
# city #501 of 613: salinopolis data processed
# city #502 of 613: sao vicente data processed
# city #503 of 613: parry sound data processed
# city #504 of 613: castillos data processed
# city #505 of 613: alto barinas data processed
# city #506 of 613: phan rang-thap cham data processed
# city #507 of 613: hopelchen data processed
# city #508 of 613: greenville data processed
# city #509 of 613: ingeniero guillermo n. juarez data processed
# city #511 of 613: desaguadero data processed
# city #512 of 613: gubkinskiy data processed
# city #513 of 613: zhigalovo data processed
# city #514 of 613: takamaka data unavailable
# city #515 of 613: kerikeri data processed
# city #516 of 613: dapa data processed
# city #517 of 613: santiago de cao data processed
# city #518 of 613: pucheng data processed
# city #519 of 613: semporna data processed
# city #520 of 613: saguenay data processed
# city #521 of 613: kavaratti data processed
# city #522 of 613: katsuren-haebaru data processed
# city #523 of 613: vilyuysk data processed
# city #524 of 613: dubbo data processed
# city #525 of 613: arish data processed
# city #526 of 613: mersing data processed
# city #527 of 613: bom jardim data processed
# city #528 of 613: petukhovo data processed
# city #529 of 613: monforte de lemos data processed
# city #530 of 613: awjilah data processed
# city #531 of 613: chulakkurgan data processed
# city #532 of 613: dambai data unavailable
# city #533 of 613: vingt cinq data unavailable
# city #534 of 613: byron bay data processed
# city #535 of 613: kawardha data processed
# city #536 of 613: essaouira data processed
# city #537 of 613: darwin data processed
# city #538 of 613: salem data processed
# city #539 of 613: fort bragg data processed
# city #540 of 613: kisangani data processed
# city #541 of 613: virginia data processed
# city #542 of 613: cambria data processed
# city #543 of 613: itacarambi data processed
# city #544 of 613: ashland data processed
# city #545 of 613: sao jose da coroa grande data processed
# city #546 of 613: jwaneng data processed
# city #547 of 613: rifle data processed
# city #548 of 613: changling data processed
# city #549 of 613: alofi data processed
# city #550 of 613: sona data processed
# city #551 of 613: cataingan data processed
# city #552 of 613: asia data processed
# city #553 of 613: sishilichengzi data unavailable
# city #554 of 613: kulhudhuffushi data processed
# city #555 of 613: puerto baquerizo moreno data processed
# city #556 of 613: landau in der pfalz data processed
# city #557 of 613: zouerate data processed
# city #558 of 613: fallsburg data processed
# city #559 of 613: papao data processed
# city #560 of 613: nguigmi data processed
# city #562 of 613: belo sur tsiribihina data processed
# city #563 of 613: trinidad data processed
# city #564 of 613: nhamunda data processed
# city #565 of 613: soria data processed
# city #566 of 613: guane data processed
# city #567 of 613: zhelezinka data processed
# city #568 of 613: temozon data processed
# city #569 of 613: zunheboto data processed
# city #570 of 613: sylvan lake data processed
# city #571 of 613: tangalle data processed
# city #572 of 613: fomboni data processed
# city #573 of 613: kalajoki data processed
# city #574 of 613: punta del este data processed
# city #575 of 613: quellon data processed
# city #576 of 613: kulia village data unavailable
# city #577 of 613: vila do maio data processed
# city #578 of 613: marka data processed
# city #579 of 613: kokoda data processed
# city #580 of 613: altai data processed
# city #581 of 613: bismarck data processed
# city #582 of 613: jalai nur data processed
# city #583 of 613: black point data processed
# city #584 of 613: saint-philippe data processed
# city #585 of 613: ilha de mocambique data processed
# city #586 of 613: sturgis data processed
# city #587 of 613: thunder bay data processed
# city #588 of 613: mindelo data processed
# city #589 of 613: ulsan data processed
# city #590 of 613: sisimiut data processed
# city #591 of 613: puerto lempira data processed
# city #592 of 613: minas de marcona data processed
# city #593 of 613: kuala terengganu data processed
# city #594 of 613: dassa-zoume data processed
# city #595 of 613: la sarre data processed
# city #596 of 613: manokwari data processed
# city #597 of 613: ouarzazat data processed
# city #598 of 613: smithers data processed
# city #599 of 613: inarajan village data processed
# city #600 of 613: molochnoye data processed
# city #601 of 613: kish data processed
# city #602 of 613: horta data processed
# city #603 of 613: aranda de duero data processed
# city #604 of 613: ust'-kut data processed
# city #605 of 613: veymandoo data unavailable
# city #606 of 613: daru data processed
# city #607 of 613: emerald data processed
# city #608 of 613: arkhara data processed
# city #609 of 613: falam data processed
# city #610 of 613: aquiraz data processed
# city #611 of 613: ginir data processed
# city #613 of 613: camana data processed
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/5k/k2z13ft93tl12wvdks82c4pc0000gn/T/ipykernel_44101/3244874227.py in <module>
#      45                           'Wind Speed': wind_speed,
#      46                           'Country': country,
# ---> 47                           'Date': date})
#
# ~/anaconda3/envs/dev/lib/python3.7/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     612         elif isinstance(data, dict):
#     613             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 614             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     615         elif isinstance(data, ma.MaskedArray):
#     616             import numpy.ma.mrecords as mrecords
#
# ~/anaconda3/envs/dev/lib/python3.7/site-packages/pandas/core/internals/construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     463
#     464     return arrays_to_mgr(
# --> 465         arrays, data_names, index, columns, dtype=dtype, typ=typ, consolidate=copy
#     466     )
#     467
#
# ~/anaconda3/envs/dev/lib/python3.7/site-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity, typ, consolidate)
#     117         # figure out the index, if necessary
#     118         if index is None:
# --> 119             index = _extract_index(arrays)
#     120         else:
#     121             index = ensure_index(index)
#
# ~/anaconda3/envs/dev/lib/python3.7/site-packages/pandas/core/internals/construction.py in _extract_index(data)
#     633             lengths = list(set(raw_lengths))
#     634             if len(lengths) > 1:
# --> 635                 raise ValueError("All arrays must be of the same length")
#     636
#     637             if have_dicts:
#
# ValueError: All arrays must be of the same length

# %%
print('cities')
len(valid_cities)
print('lat')
len(lat)
print('lng')
len(lng)
print('max temp')
len(max_temp)
print('cities')
len(valid_cities)
print('cities')
len(valid_cities)
print('cities')
len(valid_cities)
print('cities')
len(valid_cities)
print('cities')
len(valid_cities)
# Out:
# cities
# 601

# %% [raw]
# url = "https://api.openweathermap.org/data/2.5/weather?"
# city = 'toamasina'
# query_url = f"{url}appid={weather_api_key}&q={city}"
# weather_response = requests.get(query_url)
# weather_json = weather_response.json()
# weather_json

# %% [raw]
# valid_cities.append(city)
# lat.append(weather_json['coord']['lat'])
# lng.append(weather_json['coord']['lon'])
# max_temp.append(weather_json['main']['temp_max'])
# humidity.append(weather_json['main']['humidity'])
# cloudiness.append(weather_json['clouds']['all'])
# wind_speed.append(weather_json['wind']['speed'])
# country.append(weather_json['sys']['country'])
# date.append(weather_json['dt'])
# city_data = pd.DataFrame({'City': valid_cities,
#                           'Lat': lat,
#                           'Long': lng,
#                           'Max Temp': max_temp,
#                           'Humidity': humidity,
#                           'Cloudiness': cloudiness,
#                           'Wind Speed': wind_speed,
#                           'Country': country,
#                           'Date': date})

# %%
city_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/5k/k2z13ft93tl12wvdks82c4pc0000gn/T/ipykernel_44101/4235997543.py in <module>
# ----> 1 city_data
#
# NameError: name 'city_data' is not defined

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
